# %%
import pandas as pd
import numpy as np # linear algebra
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset_csv/train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
colType = ['int64','float64']
numCols=list(df.select_dtypes(include=colType).columns)
df=df[numCols]

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('SalePrice',axis=1),df['SalePrice'],test_size=.2,random_state=1)

X_train.shape,X_test.shape
# Out:
# ((1168, 37), (292, 37))

# %%
X_train.fillna(0,inplace=True)
X_train.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# Forward Selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
model=sfs(RandomForestRegressor(),k_features=10,forward=True,verbose=2,cv=5,n_jobs=-1,scoring='r2')
model.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    7.1s finished
# Features: 1/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    3.9s finished
# Features: 2/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    4.3s finished
# Features: 3/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    4.7s finished
# Features: 4/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    7.4s finished
# Features: 5/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:   10.8s finished
# Features: 6/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:   11.5s finished
# Features: 7/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   14.1s finished
# Features: 8/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   14.3s finished
# Features: 9/10[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  28 | elapsed:   14.4s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   14.5s finished
# Features: 10/10
# SequentialFeatureSelector(estimator=RandomForestRegressor(),
#                           k_features=(10, 10), n_jobs=-1, scoring='r2',
#                           verbose=1)

# %%
model.k_feature_names_
# Out:
# ('OverallQual',
#  'OverallCond',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'BsmtHalfBath',
#  'Fireplaces',
#  'GarageCars')

# %% [markdown]
# Backward Selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
backwardModel=sfs(RandomForestRegressor(),k_features=10,forward=False,verbose=2,cv=5,n_jobs=-1,scoring='r2')
backwardModel.fit(np.array(X_train),y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  37 | elapsed:   45.6s remaining:   21.8s
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:   59.5s finished
#
# [2023-08-31 11:08:52] Features: 36/10 -- score: 0.8422779574196024[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  36 | elapsed:   46.3s remaining:   23.1s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:   59.3s finished
#
# [2023-08-31 11:09:51] Features: 35/10 -- score: 0.8483937175346092[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  35 | elapsed:   39.9s remaining:   23.5s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   51.4s finished
#
# [2023-08-31 11:10:43] Features: 34/10 -- score: 0.8491752898405517[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  34 | elapsed:   36.5s remaining:   22.6s
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:   46.9s finished
#
# [2023-08-31 11:11:30] Features: 33/10 -- score: 0.851806329979403[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  33 | elapsed:   34.7s remaining:   25.6s
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:   44.8s finished
#
# [2023-08-31 11:12:15] Features: 32/10 -- score: 0.8541061780986212[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  32 | elapsed:   34.3s remaining:   26.6s
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:   35.6s finished
#
# [2023-08-31 11:12:50] Features: 31/10 -- score: 0.8533214841784753[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  31 | elapsed:   18.3s remaining:   17.1s
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:   35.6s finished
#
# [2023-08-31 11:13:26] Features: 30/10 -- score: 0.8509466442300628[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:   18.0s remaining:   18.0s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   34.3s finished
#
# [2023-08-31 11:14:01] Features: 29/10 -- score: 0.8498870121420273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  29 | elapsed:   18.0s remaining:   22.2s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:   33.9s finished
#
# [2023-08-31 11:14:35] Features: 28/10 -- score: 0.8495726349389378[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  28 | elapsed:   17.4s remaining:   23.2s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:   32.2s finished
#
# [2023-08-31 11:15:07] Features: 27/10 -- score: 0.8499000764838588[Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  27 | elapsed:   18.1s remaining:   30.8s
# [Parallel(n_jobs=-1)]: Done  24 out of  27 | elapsed:   31.4s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:

# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    7.4s finished
#
# [2023-08-31 11:20:17] Features: 10/10 -- score: 0.8498326079657114
# SequentialFeatureSelector(estimator=RandomForestRegressor(), forward=False,
#                           k_features=(10, 10), n_jobs=-1, scoring='r2',
#                           verbose=2)

# %%
backwardModel.k_feature_names_
# Out:
# ('2', '3', '4', '5', '6', '9', '13', '15', '16', '25')

# %% [markdown]
# Exhaustive Selection

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as efs
emodel=efs(RandomForestRegressor(),min_features=1,max_features=5,scoring='r2',n_jobs=-1)
emodel.fit(np.array(X_train),y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Koding\cnn\forward_selection.ipynb Cell 13 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Koding/cnn/forward_selection.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> from mlxtend.feature_selection import ExhaustiveFeatureSelector as efs
#       <a href='vscode-notebook-cell:/d%3A/Koding/cnn/forward_selection.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> emodel=efs(RandomForestRegressor(),min_features=1,max_features=5,scoring='r2',n_jobs=-1)
# ----> <a href='vscode-notebook-cell:/d%3A/Koding/cnn/forward_selection.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> emodel.fit(np.array(X_train),y_train)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py:444, in ExhaustiveFeatureSelector.fit(self, X, y, groups, **fit_params)
#     441 n_jobs = min(self.n_jobs, all_comb)
#     442 parallel = Parallel(n_jobs=n_jobs, pre_dispatch=self.pre_dispatch)
#     443 work = enumerate(
# --> 444     parallel(
#     445         delayed(_calc_score)(
#     446             self,
#     447             X_,
#     448             y,
#     449             list(set(c).union(self.fixed_features_group_set)),
#     450             groups=groups,
#     451             feature_groups=self.feature_groups,
#     452             **fit_params,
#     453         )
#     454         for c in candidates
#     455     )
#     456 )
#     458 try:
#     459     for iteration, (indices, cv_scores) in work:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
emodel.best_idx_
# Out:
# (2, 5, 6, 8, 9)

# %% [markdown]
# Recursive Selection

# %%
from sklearn.feature_selection import RFE

# %%
model = LinearRegression()
recur_fe = RFE(model, n_features_to_select=10, step=1)
feature = recur_fe.fit(X_train, y_train)
selected_features = pd.DataFrame({'Feature':list(X_train.columns),
                                    'Ranking':recur_fe.ranking_})
selected_features = selected_features.sort_values(by='Ranking')

print(selected_features)
# Out:
#           Feature  Ranking
# 18   BsmtHalfBath        1
# 26     GarageCars        1
# 24     Fireplaces        1
# 23   TotRmsAbvGrd        1
# 4     OverallQual        1
# 5     OverallCond        1
# 22   KitchenAbvGr        1
# 21   BedroomAbvGr        1
# 19       FullBath        1
# 17   BsmtFullBath        1
# 20       HalfBath        2
# 36         YrSold        3
# 6       YearBuilt        4
# 1      MSSubClass        5
# 7    YearRemodAdd        6
# 35         MoSold        7
# 33       PoolArea        8
# 32    ScreenPorch        9
# 16      GrLivArea       10
# 28     WoodDeckSF       11
# 8      MasVnrArea       12
# 30  EnclosedPorch       13
# 12    TotalBsmtSF       14
# 25    GarageYrBlt       15
# 31      3SsnPorch       16
# 13       1stFlrSF       17
# 14       2ndFlrSF       18
# 9      BsmtFinSF1       19
# 29    OpenPorchSF       20
# 2     LotFrontage       21
# 27     GarageArea       22
# 0              Id       23
# 15   LowQualFinSF       24
# 3         LotArea       25
# 10     BsmtFinSF2       26
# 11      BsmtUnfSF       27
# 34        MiscVal       28
